# %% [markdown]
# ## Respiratory Analysis

# %%
import pandas as pd

# %%
link = "https://raw.githubusercontent.com/carsonbennett1/Respiratory-Data-Analysis/refs/heads/main/hospital_data.csv"

dataSet = pd.read_csv(link)
df = pd.DataFrame(dataSet)
df.head(100)
# Out:
#    Week Ending Date Geographic aggregation  Number of Inpatient Beds  \
# 0        2023-08-12                     WA                   10650.0
# 1        2023-08-12                     WI                   10752.0
# 2        2023-08-12                     WV                    4813.0
# 3        2023-08-12                     WY                    1318.0
# 4        2023-08-19                     AK                    1354.0
# ..              ...                    ...                       ...
# 95       2023-08-26                     NJ                   20729.0
# 96       2023-08-26                     NM                    4049.0
# 97       2023-08-26                     NV                    6761.0
# 98       2023-08-26                     NY                   44216.0
# 99       2023-08-26                     OH                   25967.0
#
#     Number of Adult Inpatient Beds  Number of Pediatric Inpatient beds  \
# ...

# %%
covid = df.iloc[0:10]["Number of Adult COVID-19 Admissions, 18-49 years"]
covid
# Out:
# 0     26.0
# 1     10.0
# 2      3.0
# 3      4.0
# 4      3.0
# 5     72.0
# 6     24.0
# 7      0.0
# 8     23.0
# 9    410.0
# Name: Number of Adult COVID-19 Admissions, 18-49 years, dtype: float64
